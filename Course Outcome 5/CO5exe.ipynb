# %%
from bs4 import BeautifulSoup
import csv
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
webpage = requests.get('https://www.flipkart.com/mens-footwear/pr?sid=osp%2Ccil&p%5B%5D=facets.brand%255B%255D%3DADIDAS&sort=popularity&p%5B%5D=facets.brand%255B%255D%3DNike&p%5B%5D=facets.brand%255B%255D%3DREEBOK&p%5B%5D=facets.brand%255B%255D%3DAsics&p%5B%5D=facets.brand%255B%255D%3DUnder%2BArmour&p%5B%5D=facets.brand%255B%255D%3DUNDER%2BARMOUR&p%5B%5D=facets.brand%255B%255D%3DWilson&p%5B%5D=facets.brand%255B%255D%3DSalomon&p%5B%5D=facets.brand%255B%255D%3DSkechers&p%5B%5D=facets.brand%255B%255D%3DYonex&p%5B%5D=facets.brand%255B%255D%3DXtep&hpid=gOjRz026PuSyL4cg5ZWJxqp7_Hsxr70nj65vMAAFKlc=&fm=neon%2Fmerchandising&iid=M_162ca131-10ad-4f52-87a2-5aa3a8d2cdfa_1.KQKJX6UQ0LFU&ppt=hp&ppn=homepage&ssid=86uelxfx9c0000001644313948457&otracker=dynamic_omu_infinite_Men%2527s%2BFootwear%2B_10_1.dealCard.OMU_INFINITE_KQKJX6UQ0LFU&cid=KQKJX6UQ0LFU')

# %%
webpage
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(webpage.content,"html.parser")

# %%
soup
# Out:
# <!DOCTYPE doctype html>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim1.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app_modules.chunk.94b5e7.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.4eab83.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
# ...

# %%
name=soup.find_all('a',class_="IRpwTa")

# %%
name
# Out:
# [<a class="IRpwTa" href="/nike-downshifter-11-running-shoes-men/p/itm868626c6d6f3d?pid=SHOG6HBQHNNKJFXX&amp;lid=LSTSHOG6HBQHNNKJFXXFCC5GD&amp;marketplace=FLIPKART&amp;store=osp%2Fcil&amp;srno=b_1_1&amp;otracker=dynamic_omu_infinite_Men%2527s%2BFootwear%2B_10_1.dealCard.OMU_INFINITE_KQKJX6UQ0LFU&amp;fm=organic&amp;iid=dc453303-e32e-40d3-9ba9-0daa6454b753.SHOG6HBQHNNKJFXX.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=c0w4di2vwg0000001644314509917" rel="noopener noreferrer" target="_blank" title="Downshifter 11 Running Shoes For Men">Downshifter 11 Running Shoes For Men</a>,
# ...

# %%
Product_Name=[]
for i in range(0,len(name)):
  Product_Name.append(name[i].get_text())

# %%
Product_Name
# Out:
# ['Downshifter 11 Running Shoes For Men',
#  'Adifloss M Running Shoes For Men',
#  'Revolution 6 Next Nature Road Running Shoes For Men',
#  'UPCOURT 4 For Men',
#  'Tokyo 2 Badminton Shoes For Men',
#  'Rout2 Running Shoes For Men',
#  'COASTLAND Running Shoes For Men',
#  'Stunicon M Running Shoes For Men',
#  'UPCOURT 4 Badminton Shoes For Men',
#  'Rout2 Running Shoes For Men',
#  'EMERGO RUNNER Running Shoes For Men',
#  'Clear Factor M Running Shoes For Men',
#  'Revolution 4 Running Shoes For Men',
#  'Clear Factor M Running Shoes For Men',
#  'EMERGO RUNNER Running Shoes For Men',
#  'Zelt Sl 2.0 M Walking Shoes For Men',
#  'Flydoot M Running Shoes For Men',
#  'Clear Factor M Running Shoes For Men',
#  'GEL-ZARACA 5 B Running Shoes For Men',
#  'Pictoris M Running Shoes For Men',
#  'Travellar Lp Running Shoes For Men',
#  'Sprintfit Running Shoes For Men',
#  'Glenn M Running Shoes For Men',
#  'Slides',
#  'Zelt Sl 2.0 M Running Shoes For Men',
# ...

# %%
Price=soup.find_all('div',class_="_30jeq3")

# %%
Price
# Out:
# [<div class="_30jeq3">₹3,010</div>,
#  <div class="_30jeq3">₹2,430</div>,
#  <div class="_30jeq3">₹2,771</div>,
#  <div class="_30jeq3">₹2,699</div>,
#  <div class="_30jeq3">₹1,976</div>,
#  <div class="_30jeq3">₹1,554</div>,
#  <div class="_30jeq3">₹2,203</div>,
#  <div class="_30jeq3">₹2,552</div>,
#  <div class="_30jeq3">₹2,564</div>,
#  <div class="_30jeq3">₹1,559</div>,
#  <div class="_30jeq3">₹1,812</div>,
#  <div class="_30jeq3">₹1,424</div>,
#  <div class="_30jeq3">₹2,230</div>,
#  <div class="_30jeq3">₹1,441</div>,
#  <div class="_30jeq3">₹1,698</div>,
#  <div class="_30jeq3">₹2,107</div>,
#  <div class="_30jeq3">₹2,213</div>,
#  <div class="_30jeq3">₹1,357</div>,
#  <div class="_30jeq3">₹2,899</div>,
#  <div class="_30jeq3">₹2,100</div>,
#  <div class="_30jeq3">₹1,779</div>,
#  <div class="_30jeq3">₹1,559</div>,
#  <div class="_30jeq3">₹1,307</div>,
#  <div class="_30jeq3">₹2,097</div>,
#  <div class="_30jeq3">₹2,522</div>,
#  <div class="_30jeq3">₹1,699</div>,
# ...

# %%
Priceofp=[]
for i in range(0,len(Price)):
  Priceofp.append(Price[i].get_text())

# %%
Priceofp
# Out:
# ['₹3,010',
#  '₹2,430',
#  '₹2,771',
#  '₹2,699',
#  '₹1,976',
#  '₹1,554',
#  '₹2,203',
#  '₹2,552',
#  '₹2,564',
#  '₹1,559',
#  '₹1,812',
#  '₹1,424',
#  '₹2,230',
#  '₹1,441',
#  '₹1,698',
#  '₹2,107',
#  '₹2,213',
#  '₹1,357',
#  '₹2,899',
#  '₹2,100',
#  '₹1,779',
#  '₹1,559',
#  '₹1,307',
#  '₹2,097',
#  '₹2,522',
#  '₹1,699',
#  '₹3,169',
#  '₹2,749',
#  '₹2,530',
#  '₹3,199',
#  '₹2,460',
#  '₹1,661',
#  '₹1,464',
#  '₹2,959',
#  '₹2,481',
#  '₹1,913',
#  '₹2,080',
#  '₹2,213',
#  '₹1,771',
#  '₹1,449']

# %%
import pandas as pd

# %%
df=pd.DataFrame()

# %%
df['Names']=Product_Name

# %%
df['Price']=Priceofp

# %%
df
# Out:
#                                                 Names   Price
# 0                Downshifter 11 Running Shoes For Men  ₹3,010
# 1                    Adifloss M Running Shoes For Men  ₹2,430
# 2   Revolution 6 Next Nature Road Running Shoes Fo...  ₹2,771
# 3                                   UPCOURT 4 For Men  ₹2,699
# 4                     Tokyo 2 Badminton Shoes For Men  ₹1,976
# 5                         Rout2 Running Shoes For Men  ₹1,554
# 6                     COASTLAND Running Shoes For Men  ₹2,203
# 7                    Stunicon M Running Shoes For Men  ₹2,552
# 8                   UPCOURT 4 Badminton Shoes For Men  ₹2,564
# 9                         Rout2 Running Shoes For Men  ₹1,559
# 10                EMERGO RUNNER Running Shoes For Men  ₹1,812
# 11               Clear Factor M Running Shoes For Men  ₹1,424
# 12                 Revolution 4 Running Shoes For Men  ₹2,230
# 13               Clear Factor M Running Shoes For Men  ₹1,441
# ...
